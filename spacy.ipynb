# %%
# !python3 -m spacy download fr_core_news_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 MB 4.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_md')

# %%
import spacy
import fr_core_news_md

# %%
nlp = spacy.load('en_core_web_sm')
nlp1 = fr_core_news_md.load()

# %%
with open('oil_gas.txt', 'r') as f:
  text = f.read()

# %%
print(text)
# Out:
# NOTICE: The text below was created automatically and may contain errors and differences from the contract's original PDF file. Learn more here
# MODEL PRODUCTION SHARING CONTRACT 2008
#
#
#
# BANGLADESH OIL, GAS AND MINERAL CORPORATION
#
# (PETROBANGLA)
#
# 3 KAWRAN BAZAR COMMERCIAL AREA
#
# DHAKA-1215
#
#
# ABBREVIATIONS
#
# APPI
#
#
#
# Asian Petroleum Price Index
#
#
#
# AWP and B
#
#
#
# Abandonment Work Program and Budget
#
#
#
# BBL
#
#
#
# Barrel
#
#
#
# BCF
#
#
#
# Billion Cubic Feet (109 Cubic Feet)
#
#
#
# BTU
#
#
#
# British Thermal Unit
#
#
#
# CIF
#
#
#
# Cost, Insurance and Freight
#
#
#
# CST
#
#
#
# Centi Stoke
#
#
#
# EED
#
#
#
# Energy Exploration and Development
#
#
#
# EIA
#
#
#
# Environmental Impact Assessment
#
#
#
# EMP
#
#
#
# Environmental Management Plan
#
#
#
# FOB
#
#
#
# Free On Board
#
#
#
# HSFO
#
#
#
# High Sulphur Fuel Oil at 180 Centi Stokes (maximum)
#
#
#
# ICSID
#
#
#
# International Center for the Settlement of Investment Disputes
#
#
#
# IEE
#
# ...

# %%
doc = nlp(text)

# %%
print(doc)
# Out:
# NOTICE: The text below was created automatically and may contain errors and differences from the contract's original PDF file. Learn more here
# MODEL PRODUCTION SHARING CONTRACT 2008
#
#
#
# BANGLADESH OIL, GAS AND MINERAL CORPORATION
#
# (PETROBANGLA)
#
# 3 KAWRAN BAZAR COMMERCIAL AREA
#
# DHAKA-1215
#
#
# ABBREVIATIONS
#
# APPI
#
#
#
# Asian Petroleum Price Index
#
#
#
# AWP and B
#
#
#
# Abandonment Work Program and Budget
#
#
#
# BBL
#
#
#
# Barrel
#
#
#
# BCF
#
#
#
# Billion Cubic Feet (109 Cubic Feet)
#
#
#
# BTU
#
#
#
# British Thermal Unit
#
#
#
# CIF
#
#
#
# Cost, Insurance and Freight
#
#
#
# CST
#
#
#
# Centi Stoke
#
#
#
# EED
#
#
#
# Energy Exploration and Development
#
#
#
# EIA
#
#
#
# Environmental Impact Assessment
#
#
#
# EMP
#
#
#
# Environmental Management Plan
#
#
#
# FOB
#
#
#
# Free On Board
#
#
#
# HSFO
#
#
#
# High Sulphur Fuel Oil at 180 Centi Stokes (maximum)
#
#
#
# ICSID
#
#
#
# International Center for the Settlement of Investment Disputes
#
#
#
# IEE
#
# ...

# %%
print(len(doc))
print(len(text))
# Out:
# 49503
# 257285

# %%
for token in text[:10]:
  print(token)
# Out:
# N
# O
# T
# I
# C
# E
# :
#
# T

# %%
for token in doc[:10]:
  print(token)
# Out:
# NOTICE
# :
# The
# text
# below
# was
# created
# automatically
# and
# may

# %%
for token in text.split()[:10]:
  print(token)
# Out:
# NOTICE:
# The
# text
# below
# was
# created
# automatically
# and
# may
# contain

# %%
words = text.split()[:10]

# %%
i = 5
for token in doc[i:8]:
  print(f"Spacy Token {i}:\n{token}\nWord split {i}: \n {words[i]}\n\n")
  i =i+1
# Out:
# Spacy Token 5:
# was
# Word split 5:
#  created
#
#
# Spacy Token 6:
# created
# Word split 6:
#  automatically
#
#
# Spacy Token 7:
# automatically
# Word split 7:
#  and

# %%
for sent in doc.sents:
  print(sent)
# Out:
# NOTICE: The text below was created automatically and may contain errors and differences from the contract's original PDF file.
# Learn more here
# MODEL PRODUCTION SHARING CONTRACT 2008
#
#
#
# BANGLADESH OIL, GAS AND MINERAL CORPORATION
#
# (PETROBANGLA)
#
# 3 KAWRAN BAZAR COMMERCIAL AREA
#
# DHAKA-1215
#
#
# ABBREVIATIONS
#
# APPI
#
#
#
# Asian Petroleum Price Index
#
#
#
# AWP and B
#
#
#
# Abandonment Work Program and Budget
#
#
#
# BBL
#
#
#
# Barrel
#
#
#
# BCF
#
#
#
# Billion Cubic Feet (109 Cubic Feet)
#
#
#
# BTU
#
#
#
# British Thermal Unit
#
#
#
# CIF
#
#
#
# Cost, Insurance and Freight
#
#
#
# CST
#
#
#
# Centi Stoke
#
#
#
# EED
#
#
#
# Energy Exploration and Development
#
#
#
# EIA
#
#
#
# Environmental Impact Assessment
#
#
#
# EMP
#
#
#
# Environmental Management Plan
#
#
#
# FOB
#
#
#
# Free On Board
#
#
#
# HSFO
#
#
#
# High Sulphur Fuel Oil at 180 Centi Stokes (maximum)
#
#
#
# ICSID
#
#
#
# International Center for the Settlement of Investment Disputes
#
#
#
# IEE
# ...

# %%
sentence1 = doc.sents[0]
print(sentence1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sentence1 = doc.sents[0]
#       2 print(sentence1)
#
# TypeError: 'generator' object is not subscriptable

# %% [markdown]
# Getting first sentence using list to make into unhashable.

# %%
sentence1 = list(doc.sents)[0]
print(sentence1)
# Out:
# NOTICE: The text below was created automatically and may contain errors and differences from the contract's original PDF file.

# %%
token2 = sentence1[3]
print(token2)
# Out:
# text

# %%
token2.text
# Out:
# 'text'

# %% [markdown]
# The syntactic parento of this token.

# %%
token2.head
# Out:
# created

# %%
token2.right_edge
# Out:
# below

# %% [markdown]
# In linguistics and natural language processing, the syntactic head is a concept that refers to a word within a phrase or a sentence that governs the behavior of other words in that phrase or sentence. The head is typically the most important word in the phrase and determines the grammatical structure and interpretation of the entire phrase.

# %%
token2.left_edge
# Out:
# The

# %%
token2.ent_iob_
# Out:
# 'O'

# %%
token2.lemma_
# Out:
# 'text'

# %% [markdown]
# Morphological analysis is a linguistic process that involves the study and identification of the internal structure and forms of words. It examines how words are formed, their component morphemes (the smallest units of meaning), and the rules or patterns that govern their formation.

# %%
token2.morph
# Out:
# Number=Sing

# %% [markdown]
# POS = Part of Speech

# %%
token2.pos_
# Out:
# 'NOUN'

# %%
token2.lang_
# Out:
# 'en'

# %% [markdown]
# Spacy offers an easy way to parse a text and identify its parts of speech. Iterating accross each token (word or punctuation) in the text and identify its parts of speech.

# %%
for token in sentence1:
  print(token.text, token.pos_, token.dep_)
# Out:
# NOTICE PROPN ROOT
# : PUNCT punct
# The DET det
# text NOUN nsubjpass
# below ADV advmod
# was AUX auxpass
# created VERB acl
# automatically ADV advmod
# and CCONJ cc
# may AUX aux
# contain VERB conj
# errors NOUN dobj
# and CCONJ cc
# differences NOUN conj
# from ADP prep
# the DET det
# contract NOUN poss
# 's PART case
# original ADJ amod
# PDF NOUN compound
# file NOUN pobj
# . PUNCT punct

# %%
from spacy import displacy

# %% [markdown]
# We can render the outflow in svg file also.

# %%
displacy.render(sentence1, style = 'dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="95d07479f597414ba81d75e4d0fe88e1-0" class="displacy" width="3550" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">﻿NOTICE:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %% [markdown]
# Entity Recognition: It is essenstial task of NLP

# %% [markdown]
# GPE: Geo political Entity
# ORG: Orgnization
# Cardinal: Number
# ]

# %%
for ent in doc.ents:
  print(ent.label_,ent.text)
# Out:
# CARDINAL ﻿NOTICE
# ORG PDF
# DATE 2008
# ORG BANGLADESH OIL
# ORG GAS
# PERSON CORPORATION
# CARDINAL 3
# ORG KAWRAN
# NORP Asian
# ORG Budget
# PERSON Barrel
# ORG BCF
# QUANTITY Billion Cubic Feet
# QUANTITY 109 Cubic Feet
# ORG BTU
# NORP British
# ORG CIF
# ORG CST
# PERSON Centi Stoke
# ORG Energy Exploration and Development
# CARDINAL 180
# PERSON Centi Stokes
# ORG ICSID
# ORG the Settlement of Investment Disputes
# ORG Initial Environmental Examination
# ORG London Inter Bank
# ORG LNG
# ORG Liquefied Natural Gas
# ORG MCF
# QUANTITY Thousand Cubic Feet
# QUANTITY Million Cubic Feet
# PRODUCT Standard Cubic Feet
# ORG Society of Petroleum Engineers
# ORG TCF
# LAW Trillion Cubic Feet
# DATE 1012
# ORG United Nations Commission on
# ORG International Trade Law Arbitration
# CARDINAL 2
# GPE Dhaka
# DATE this______(day
# CARDINAL 1
# ORG Energy and Mineral Resources Division
# ORG Ministry of Power, Energy and Mineral
#
# ...

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ﻿NOTICE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : The text below was created automatically and may contain errors and differences from the contract's original
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PDF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  file. Learn more here</br>MODEL PRODUCTION SHARING CONTRACT
# ...

# %%
pip install translate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 2.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from translate import Translator

# %%
translator =  Translator(to_lang = 'fr')
translator = translator.translate('I love you.')
print(translator)
# Out:
# Je t’aime.

# %%
import nltk
